# %% [markdown]
# This Notebook has been created to build the code to scrape the given Wikipedia page to obtain the data that is in the table of postal codes and to transform the data into a pandas dataframe.
#
# Import pandas numpy

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests

# %%
wikipedia_link='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %% [markdown]
# uploading the wikipedia_link

# %%
wikipedia_link='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
raw_wikipedia_page= requests.get(wikipedia_link)
url  = requests.get(wikipedia_link).text
soup = BeautifulSoup(url,'lxml')
#print(soup.prettify())

# %% [markdown]
#  Import the column names Postal code, Borough and Neighborhood.

# %% [markdown]
# Defining Variables and code.  Data had=s been stored as a text file.

# %%
table = soup.find('table')

Postcode      = []
Borough       = []
Neighbourhood = []

# print(table)

# extracting a clean form of the table
for tr_cell in table.find_all('tr'):
    
    counter = 1
    Postcode_var      = -1
    Borough_var       = -1
    Neighbourhood_var = -1
    
    for td_cell in tr_cell.find_all('td'):
        if counter == 1: 
            Postcode_var = td_cell.text
        if counter == 2: 
            Borough_var = td_cell.text
            tag_a_Borough = td_cell.find('a')
            
        if counter == 3: 
            Neighbourhood_var = str(td_cell.text).strip()
            tag_a_Neighbourhood = td_cell.find('a')
            
        counter +=1
        
    if (Postcode_var == 'Not assigned' or Borough_var == 'Not assigned' or Neighbourhood_var == 'Not assigned'): 
        continue
    try:
        if ((tag_a_Borough is None) or (tag_a_Neighbourhood is None)):
            continue
    except:
        pass
    if(Postcode_var == -1 or Borough_var == -1 or Neighbourhood_var == -1):
        continue
        
    Postcode.append(Postcode_var)
    Borough.append(Borough_var)
    Neighbourhood.append(Neighbourhood_var)

# %%
toronto_dict = {'Postcode':Postcode_u, 'Borough':Borough_u, 'Neighbourhood':Neighbourhood_u}
df_toronto = pd.DataFrame.from_dict(toronto_dict)
df_toronto.to_csv('toronto_part1.csv')
df_toronto.head(76)
# Out:
#    Postcode           Borough  \
# 0       M8Z         Etobicoke
# 1       M1X       Scarborough
# 2       M3L        North York
# 3       M4C         East York
# 4       M1J       Scarborough
# 5       M8W         Etobicoke
# 6       M1R       Scarborough
# 7       M9A  Downtown Toronto
# 8       M6A        North York
# 9       M4B         East York
# 10      M4L      East Toronto
# 11      M3C        North York
# 12      M1V       Scarborough
# 13      M4W  Downtown Toronto
# 14      M1S       Scarborough
# 15      M2R        North York
# 16      M4X  Downtown Toronto
# 17      M5P   Central Toronto
# 18      M4Y  Downtown Toronto
# 19      M5L  Downtown Toronto
# 20      M2J        North York
# 21      M2K        North York
# 22      M5M        North York
# 23      M4N   Central Toronto
# 24      M4T   Central Toronto
# 25      M5T  Downtown Toronto
# 26      M8X         Etobicoke
# 27      M3H        North York
# 28      M1E       Scarborough
# 29      M3J        North York
# 30      M3K        North York
# 31      M1B       Scarborough
# 32      M6K      West Toronto
# 33      M8V         Etobicoke
# 34      M4A        North York
# 35      M1K       Scarborough
# 36      M1L       Scarborough
# 37      M1N       Scarborough
# 38      M5K  Downtown Toronto
# 39      M9N              York
# 40      M2H        North York
# 41      M1C       Scarborough
# 42      M1M       Scarborough
# 43      M9R         Etobicoke
# 44      M6J      West Toronto
# 45      M5S  Downtown Toronto
# 46      M9V         Etobicoke
# 47      M8Y         Etobicoke
# 48      M6S      West Toronto
# 49      M9M        North York
# 50      M4H         East York
# 51      M3A        North York
# 52      M4V   Central Toronto
# 53      M5J  Downtown Toronto
# 54      M5E  Downtown Toronto
# 55      M6H      West Toronto
# 56      M6P      West Toronto
# 57      M1G       Scarborough
# 58      M5R   Central Toronto
# 59      M4E      East Toronto
# 60      M5C  Downtown Toronto
# 61      M4K      East Toronto
# 62      M9C         Etobicoke
# 63      M4J         East York
# 64      M6L        North York
# 65      M5X  Downtown Toronto
# 66      M5V  Downtown Toronto
# 67      M1T       Scarborough
# 68      M6M              York
# 69      M5A  Downtown Toronto
# 70      M9L        North York
# 71      M2M        North York
# 72      M1P       Scarborough
# 73      M2L        North York
# 74      M9B         Etobicoke
# 75      M6R      West Toronto
#
#                                         Neighbourhood
# 0                       Mimico NW, The Queensway West
# 1                                         Upper Rouge
# 2                                      Downsview West
# 3                                    Woodbine Heights
# 4                                 Scarborough Village
# 5                              Alderwood, Long Branch
# 6                                   Maryvale, Wexford
# 7                                        Queen's Park
# 8                    Lawrence Heights, Lawrence Manor
# 9                     Woodbine Gardens, Parkview Hill
# 10                                       India Bazaar
# 11                                    Flemingdon Park
# 12                          Agincourt North, Milliken
# 13                                           Rosedale
# 14                                          Agincourt
# 15                                    Willowdale West
# 16                        Cabbagetown, St. James Town
# 17                                  Forest Hill North
# 18                               Church and Wellesley
# 19                                     Commerce Court
# 20                                         Henry Farm
# 21                                    Bayview Village
# 22                                       Bedford Park
# 23                                      Lawrence Park
# 24                                         Moore Park
# 25          Chinatown, Grange Park, Kensington Market
# 26                                       The Kingsway
# 27                     Bathurst Manor, Wilson Heights
# 28                             Morningside, West Hill
# 29                    Northwood Park, York University
# 30                                        CFB Toronto
# 31                                     Rouge, Malvern
# 32                 Exhibition Place, Parkdale Village
# 33                                        New Toronto
# 34                                   Victoria Village
# 35                              Ionview, Kennedy Park
# 36                    Clairlea, Golden Mile, Oakridge
# 37                                        Birch Cliff
# 38           Design Exchange, Toronto Dominion Centre
# 39                                             Weston
# 40                                  Hillcrest Village
# 41             Highland Creek, Rouge Hill, Port Union
# 42                              Cliffcrest, Cliffside
# 43                                  Kingsview Village
# 44                           Little Portugal, Trinity
# 45                              University of Toronto
# 46  Beaumond Heights, Jamestown, Mount Olive, Silv...
# 47  Humber Bay, Mimico NE, Old Mill South, The Que...
# 48                                 Runnymede, Swansea
# 49                                   Emery, Humberlea
# 50                                   Thorncliffe Park
# 51                                          Parkwoods
# 52                   Deer Park, Rathnelly, South Hill
# 53                     Toronto Islands, Union Station
# 54                                        Berczy Park
# 55                                 Dovercourt Village
# 56                                          High Park
# 57                                             Woburn
# 58                               The Annex, Yorkville
# 59                                        The Beaches
# 60                                     St. James Town
# 61                                          Riverdale
# 62                                      Markland Wood
# 63                                       East Toronto
# 64                                          Downsview
# 65             First Canadian Place, Underground city
# 66  CN Tower, King and Spadina, Railway Lands, Sou...
# 67                                      Tam O'Shanter
# 68              Keelesdale, Mount Dennis, Silverthorn
# 69                                       Harbourfront
# 70                                      Humber Summit
# 71                            Newtonbrook, Willowdale
# 72  Dorset Park, Scarborough Town Centre, Wexford ...
# 73                                         York Mills
# 74       Islington, Princess Gardens, West Deane Park
# 75                             Parkdale, Roncesvalles

# %% [markdown]
# Cleaning the neiborhood.

# %%
Neighbourhood = [n.replace(')','') for n in Neighbourhood]
Neighbourhood = [n.replace('/',',') for n in Neighbourhood]
Neighbourhood = [n.replace('(',',') for n in Neighbourhood]

#convert the dict to dataframe
df=pd.DataFrame.from_dict(dc_toronto)

# %%
df_toronto.shape
# Out:
# (77, 3)

# %% [raw]
# Generating Dataframe

# %%
df = pd.DataFrame()
df['Postcode']=postcode
df['Borough']= Borough
df['Neighbourhood']=Neighbourhood
df_post = df[ df.Borough != 'Not assigned']
df_post.reset_index(drop=True)
# Out:
#      Postcode           Borough            Neighbourhood
# 0         NaN        North York                Parkwoods
# 1         NaN        North York         Victoria Village
# 2         NaN  Downtown Toronto             Harbourfront
# 3         NaN        North York         Lawrence Heights
# 4         NaN        North York           Lawrence Manor
# 5         NaN  Downtown Toronto             Queen's Park
# 6         NaN       Scarborough                    Rouge
# 7         NaN       Scarborough                  Malvern
# 8         NaN         East York         Woodbine Gardens
# 9         NaN         East York            Parkview Hill
# 10        NaN         Etobicoke                Islington
# 11        NaN         Etobicoke         Princess Gardens
# 12        NaN         Etobicoke          West Deane Park
# 13        NaN       Scarborough           Highland Creek
# 14        NaN       Scarborough               Rouge Hill
# 15        NaN       Scarborough               Port Union
# 16        NaN        North York          Flemingdon Park
# 17        NaN         East York         Woodbine Heights
# 18        NaN  Downtown Toronto           St. James Town
# 19        NaN         Etobicoke            Markland Wood
# 20        NaN       Scarborough              Morningside
# 21        NaN       Scarborough                West Hill
# 22        NaN      East Toronto              The Beaches
# 23        NaN  Downtown Toronto              Berczy Park
# 24        NaN       Scarborough                   Woburn
# 25        NaN         East York                  Leaside
# 26        NaN        North York        Hillcrest Village
# 27        NaN        North York           Bathurst Manor
# 28        NaN        North York           Wilson Heights
# 29        NaN         East York         Thorncliffe Park
# 30        NaN      West Toronto       Dovercourt Village
# 31        NaN       Scarborough      Scarborough Village
# 32        NaN        North York               Henry Farm
# 33        NaN        North York           Northwood Park
# 34        NaN        North York          York University
# 35        NaN         East York             East Toronto
# 36        NaN  Downtown Toronto          Toronto Islands
# 37        NaN  Downtown Toronto            Union Station
# 38        NaN      West Toronto          Little Portugal
# 39        NaN      West Toronto                  Trinity
# 40        NaN       Scarborough                  Ionview
# 41        NaN       Scarborough             Kennedy Park
# 42        NaN        North York          Bayview Village
# 43        NaN        North York              CFB Toronto
# 44        NaN      East Toronto                Riverdale
# 45        NaN  Downtown Toronto          Design Exchange
# 46        NaN  Downtown Toronto  Toronto Dominion Centre
# 47        NaN      West Toronto         Exhibition Place
# 48        NaN      West Toronto         Parkdale Village
# 49        NaN       Scarborough                 Clairlea
# 50        NaN       Scarborough              Golden Mile
# 51        NaN       Scarborough                 Oakridge
# 52        NaN        North York               York Mills
# 53        NaN        North York           Downsview West
# 54        NaN      East Toronto             India Bazaar
# 55        NaN  Downtown Toronto           Commerce Court
# 56        NaN        North York                Downsview
# 57        NaN        North York            Humber Summit
# 58        NaN       Scarborough               Cliffcrest
# 59        NaN       Scarborough                Cliffside
# 60        NaN        North York              Newtonbrook
# 61        NaN        North York               Willowdale
# 62        NaN        North York             Bedford Park
# 63        NaN              York               Keelesdale
# 64        NaN              York             Mount Dennis
# 65        NaN              York              Silverthorn
# 66        NaN        North York                    Emery
# 67        NaN        North York                Humberlea
# 68        NaN       Scarborough              Birch Cliff
# 69        NaN   Central Toronto            Lawrence Park
# 70        NaN              York                   Weston
# 71        NaN       Scarborough              Dorset Park
# 72        NaN       Scarborough  Scarborough Town Centre
# 73        NaN       Scarborough          Wexford Heights
# 74        NaN   Central Toronto        Forest Hill North
# 75        NaN      West Toronto                High Park
# 76        NaN       Scarborough                 Maryvale
# 77        NaN       Scarborough                  Wexford
# 78        NaN        North York          Willowdale West
# 79        NaN   Central Toronto                The Annex
# 80        NaN   Central Toronto                Yorkville
# 81        NaN      West Toronto                 Parkdale
# 82        NaN      West Toronto             Roncesvalles
# 83        NaN         Etobicoke        Kingsview Village
# 84        NaN       Scarborough                Agincourt
# 85        NaN  Downtown Toronto    University of Toronto
# 86        NaN      West Toronto                Runnymede
# 87        NaN      West Toronto                  Swansea
# 88        NaN       Scarborough            Tam O'Shanter
# 89        NaN   Central Toronto               Moore Park
# 90        NaN  Downtown Toronto                Chinatown
# 91        NaN  Downtown Toronto              Grange Park
# 92        NaN  Downtown Toronto        Kensington Market
# 93        NaN       Scarborough          Agincourt North
# 94        NaN       Scarborough                 Milliken
# 95        NaN   Central Toronto                Deer Park
# 96        NaN   Central Toronto                Rathnelly
# 97        NaN   Central Toronto               South Hill
# 98        NaN  Downtown Toronto                 CN Tower
# 99        NaN  Downtown Toronto         King and Spadina
# 100       NaN  Downtown Toronto            Railway Lands
# 101       NaN  Downtown Toronto            South Niagara
# 102       NaN         Etobicoke              New Toronto
# 103       NaN         Etobicoke         Beaumond Heights
# 104       NaN         Etobicoke                Jamestown
# 105       NaN         Etobicoke              Mount Olive
# 106       NaN         Etobicoke              Silverstone
# 107       NaN         Etobicoke            South Steeles
# 108       NaN         Etobicoke              Thistletown
# 109       NaN  Downtown Toronto                 Rosedale
# 110       NaN         Etobicoke                Alderwood
# 111       NaN         Etobicoke              Long Branch
# 112       NaN       Scarborough              Upper Rouge
# 113       NaN  Downtown Toronto              Cabbagetown
# 114       NaN  Downtown Toronto           St. James Town
# 115       NaN  Downtown Toronto     First Canadian Place
# 116       NaN  Downtown Toronto         Underground city
# 117       NaN         Etobicoke             The Kingsway
# 118       NaN  Downtown Toronto     Church and Wellesley
# 119       NaN         Etobicoke               Humber Bay
# 120       NaN         Etobicoke                Mimico NE
# 121       NaN         Etobicoke           Old Mill South
# 122       NaN         Etobicoke       The Queensway East
# 123       NaN         Etobicoke    Royal York South East
# 124       NaN         Etobicoke                 Sunnylea
# 125       NaN         Etobicoke                Mimico NW
# 126       NaN         Etobicoke       The Queensway West

# %% [markdown]
# Using Shape

# %%
df_post.shape
# Out:
# (127, 3)
